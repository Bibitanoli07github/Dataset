# %% [markdown]
# ## HAJRA BIBI
# ## 2k24/TYCS/2

# %% [markdown]
# # GRAPH PLOT

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[1,2,3,4])
plt.ylabel("numbers y")
plt.xlabel("numbers x")
plt.title("LINE PLOT")
plt.show()
